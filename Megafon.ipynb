# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline  
# %config InlineBackend.figure_format = 'svg'
pd.options.display.max_columns = None

# %%
train_fn = 'data_train.csv'
test_fn = 'data_test.csv'
feat_fn = "features.csv"

# %%
df_train = pd.read_csv(train_fn, sep=',', index_col=0)
df_train = df_train.astype(np.uint32)
#df_train['buy_time'] = pd.to_datetime(df_train['buy_time'], unit='s')
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 831653 entries, 0 to 831652
# Data columns (total 4 columns):
# id          831653 non-null uint32
# vas_id      831653 non-null uint32
# buy_time    831653 non-null uint32
# target      831653 non-null uint32
# dtypes: uint32(4)
# memory usage: 19.0 MB

# %%
df_test = pd.read_csv(test_fn, sep=',', index_col=0)
df_test = df_test.astype(np.uint32)
#df_train['buy_time'] = pd.to_datetime(df_train['buy_time'], unit='s')
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71231 entries, 0 to 71230
# Data columns (total 3 columns):
# id          71231 non-null uint32
# vas_id      71231 non-null uint32
# buy_time    71231 non-null uint32
# dtypes: uint32(3)
# memory usage: 1.4 MB

# %%
# преобразование к 32-битному типу данных для уменьшения использования памятия
keys = ['id', 'buy_time']
keys.extend([str(x) for x in range(0, 252+1)])
values = [np.uint32]*2
values.extend([np.float32]*253)
col_types = dict(zip(keys, values))

# %%
# %time df_feats = pd.read_csv(feat_fn, sep='\t', index_col=0, dtype=col_types)
df_feats.info()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\lib\arraysetops.py:569: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
# Wall time: 3min 23s
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4512528 entries, 0 to 4512527
# Columns: 255 entries, id to 252
# dtypes: float32(253), uint32(2)
# memory usage: 4.3 GB

# %%
df_feats.head()
# Out:
#         id    buy_time          0           1           2           3  \
# 0  2013026  1531688400  18.910028   46.980888    4.969214   -1.386798
# 1  2014722  1539550800  36.690029  152.400894  448.069214  563.833191
# 2  2015199  1545598800 -67.019974  157.050888  -63.180786  178.103195
# 3  2021765  1534107600   7.010029  150.200882   -6.930786  216.213196
# 4  2027465  1533502800 -90.439972  134.220886 -104.380783  153.643204
#
#             4           5         6          7         8          9        10  \
# 0    3.791754  -14.011789 -16.08618 -65.076096 -6.783660 -30.006538 -2.736081
# 1  463.841766  568.998230 -16.08618 -53.216099 -6.783660 -26.544905 -2.736081
# 2  -68.598244  156.998215   3.51382  25.183903 -0.417924  -1.689642 -2.736081
# 3   76.621758  351.848206 -16.08618 -65.076096 -6.783660 -30.006538 -2.736081
# 4 -109.798248  132.538208 -16.08618 -65.076096 -6.783660 -30.006538 -2.736081
#
# ...

# %%
#df_feats.describe()

# %%
#pd.to_datetime([np.min(df_train['buy_time']), np.max(df_train['buy_time'])], unit='s')

# %%
#pd.to_datetime([np.min(df_test['buy_time']), np.max(df_test['buy_time'])], unit='s')

# %%
df_train.info()
# кол-во строк в трейне: 831653
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 831653 entries, 0 to 831652
# Data columns (total 4 columns):
# id          831653 non-null uint32
# vas_id      831653 non-null uint32
# buy_time    831653 non-null uint32
# target      831653 non-null uint32
# dtypes: uint32(4)
# memory usage: 19.0 MB

# %%
df_merge_train = df_train.merge(df_feats, on=['id'], how='left')
df_merge_train.info()
# кол-во строк в трейне увеличилось до 860052
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 860052 entries, 0 to 860051
# Columns: 258 entries, id to 252
# dtypes: float32(253), uint32(5)
# memory usage: 853.0 MB

# %%
df_test.info()
# кол-во строк в тесте: 71231
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71231 entries, 0 to 71230
# Data columns (total 3 columns):
# id          71231 non-null uint32
# vas_id      71231 non-null uint32
# buy_time    71231 non-null uint32
# dtypes: uint32(3)
# memory usage: 1.4 MB

# %%
df_merge_test = df_test.merge(df_feats, on=['id'], how='left')
df_merge_test.info()
# кол-во строк в тесте увеличилось до 73666
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 73666 entries, 0 to 73665
# Columns: 257 entries, id to 252
# dtypes: float32(253), uint32(4)
# memory usage: 72.8 MB
